# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
import pandas as pd
citybikes_df = pd.read_csv('citybikes_data.csv')
yelp_foursquare_df = pd.read_csv('yelp_foursquare.csv')

# %%
citybikes_df
# Out:
#                                     name                        station-id  \
# 0                       One Texas Center  01eedbec47378a4407f5a3fc4352fdf3
# 1                        28th/Rio Grande  57eb8e5d401aeabe67ff95e6f1f1f999
# 2                             22nd/Pearl  ed95d8e12ad7c2ec3ff0b7dd0f4673f2
# 3                          9th/Henderson  8723bfa08ec83b133f6a9aeecd075f51
# 4         South Congress @ Bouldin Creek  568256d098257d6e8433513638f5257b
# ..                                   ...                               ...
# 74  East 5th/Broadway @ Capital Metro HQ  fe9c5e51f706fdd8981ed72ebf05eab4
# 75                              6th/West  3c8c0510f41de2f9d61a1d3ed5993790
# 76                          4th/Congress  15c906ebd3955b31efa9a1dd4de8f950
# 77     11th/Congress @ The Texas Capitol  49abfbfe3cddcd1574965bef3772db3d
# 78   East 5th/Shady @ Eastside Bus Plaza  37f6489cfb4ee3ffda99e30e2c84e08c
#
#     Latitude  Longitude  Number of Bikes
# ...

# %%
citybikes_df.rename(columns={'station-id': 'station_id'}, inplace=True)

# %%
citybikes_df.drop('name', axis=1, inplace=True)
citybikes_df
# Out:
#                           station_id  Latitude  Longitude  Number of Bikes
# 0   01eedbec47378a4407f5a3fc4352fdf3  30.25759  -97.74898                5
# 1   57eb8e5d401aeabe67ff95e6f1f1f999  30.29312  -97.74412                1
# 2   ed95d8e12ad7c2ec3ff0b7dd0f4673f2  30.28540  -97.74673                7
# 3   8723bfa08ec83b133f6a9aeecd075f51  30.27217  -97.75246                3
# 4   568256d098257d6e8433513638f5257b  30.25495  -97.74755                2
# ..                               ...       ...        ...              ...
# 74  fe9c5e51f706fdd8981ed72ebf05eab4  30.25630  -97.71007               10
# 75  3c8c0510f41de2f9d61a1d3ed5993790  30.27041  -97.75046                3
# 76  15c906ebd3955b31efa9a1dd4de8f950  30.26634  -97.74378                7
# 77  49abfbfe3cddcd1574965bef3772db3d  30.27260  -97.74127                3
# 78  37f6489cfb4ee3ffda99e30e2c84e08c  30.25212  -97.69807                6
#
# [79 rows x 4 columns]

# %%
citybikes_df.rename(columns={'Number of Bikes': 'number_of_bikes'}, inplace=True)

# %%
citybikes_df
# Out:
#                           station_id  Latitude  Longitude  number_of_bikes
# 0   01eedbec47378a4407f5a3fc4352fdf3  30.25759  -97.74898                5
# 1   57eb8e5d401aeabe67ff95e6f1f1f999  30.29312  -97.74412                1
# 2   ed95d8e12ad7c2ec3ff0b7dd0f4673f2  30.28540  -97.74673                7
# 3   8723bfa08ec83b133f6a9aeecd075f51  30.27217  -97.75246                3
# 4   568256d098257d6e8433513638f5257b  30.25495  -97.74755                2
# ..                               ...       ...        ...              ...
# 74  fe9c5e51f706fdd8981ed72ebf05eab4  30.25630  -97.71007               10
# 75  3c8c0510f41de2f9d61a1d3ed5993790  30.27041  -97.75046                3
# 76  15c906ebd3955b31efa9a1dd4de8f950  30.26634  -97.74378                7
# 77  49abfbfe3cddcd1574965bef3772db3d  30.27260  -97.74127                3
# 78  37f6489cfb4ee3ffda99e30e2c84e08c  30.25212  -97.69807                6
#
# [79 rows x 4 columns]

# %%
yelp_foursquare_df
# Out:
#                     name                        station_id  category_id  \
# 0     Sandy's Hamburgers  01eedbec47378a4407f5a3fc4352fdf3        13031
# 1         Torchy’S Tacos  57eb8e5d401aeabe67ff95e6f1f1f999        13145
# 2      Pluckers Wing Bar  ed95d8e12ad7c2ec3ff0b7dd0f4673f2        13022
# 3               24 Diner  8723bfa08ec83b133f6a9aeecd075f51        13049
# 4             Aba Austin  568256d098257d6e8433513638f5257b        13000
# ..                   ...                               ...          ...
# 74       Kemuri Tatsu-ya  fe9c5e51f706fdd8981ed72ebf05eab4        13026
# 75               Irene's  3c8c0510f41de2f9d61a1d3ed5993790        13049
# 76  Modern Market Eatery  15c906ebd3955b31efa9a1dd4de8f950        13145
# 77            Chi'Lantro  49abfbfe3cddcd1574965bef3772db3d        13145
# 78   Justine's Brasserie  37f6489cfb4ee3ffda99e30e2c84e08c        13148
#
#            category_name  review_count  distance  rating  \
# ...

# %% [markdown]
# JOIN Austin Bike data to Yelp Data

# %%
combined_station_df = pd.merge(citybikes_df, yelp_foursquare_df, on='station_id', how='inner')
#df.drop_duplicates(subset='station_id', inplace=True)
combined_station_df
# Out:
#                           station_id  Latitude  Longitude  Number of Bikes  \
# 0   01eedbec47378a4407f5a3fc4352fdf3  30.25759  -97.74898                5
# 1   57eb8e5d401aeabe67ff95e6f1f1f999  30.29312  -97.74412                1
# 2   ed95d8e12ad7c2ec3ff0b7dd0f4673f2  30.28540  -97.74673                7
# 3   8723bfa08ec83b133f6a9aeecd075f51  30.27217  -97.75246                3
# 4   568256d098257d6e8433513638f5257b  30.25495  -97.74755                2
# ..                               ...       ...        ...              ...
# 74  fe9c5e51f706fdd8981ed72ebf05eab4  30.25630  -97.71007               10
# 75  3c8c0510f41de2f9d61a1d3ed5993790  30.27041  -97.75046                3
# 76  15c906ebd3955b31efa9a1dd4de8f950  30.26634  -97.74378                7
# 77  49abfbfe3cddcd1574965bef3772db3d  30.27260  -97.74127                3
# 78  37f6489cfb4ee3ffda99e30e2c84e08c  30.25212  -97.69807                6
#
# ...

# %%
combined_station_df.to_csv("final_station_data.csv", index = False)

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %% [markdown]
# EDA will be performed on the final_stations data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(color_codes=True)

# %% [markdown]
# Load data into DataFrame

# %%
df = pd.read_csv("final_station_data.csv")
df
# Out:
#                           station_id  Latitude  Longitude  Number of Bikes  \
# 0   01eedbec47378a4407f5a3fc4352fdf3  30.25759  -97.74898                5
# 1   57eb8e5d401aeabe67ff95e6f1f1f999  30.29312  -97.74412                1
# 2   ed95d8e12ad7c2ec3ff0b7dd0f4673f2  30.28540  -97.74673                7
# 3   8723bfa08ec83b133f6a9aeecd075f51  30.27217  -97.75246                3
# 4   568256d098257d6e8433513638f5257b  30.25495  -97.74755                2
# ..                               ...       ...        ...              ...
# 74  fe9c5e51f706fdd8981ed72ebf05eab4  30.25630  -97.71007               10
# 75  3c8c0510f41de2f9d61a1d3ed5993790  30.27041  -97.75046                3
# 76  15c906ebd3955b31efa9a1dd4de8f950  30.26634  -97.74378                7
# 77  49abfbfe3cddcd1574965bef3772db3d  30.27260  -97.74127                3
# 78  37f6489cfb4ee3ffda99e30e2c84e08c  30.25212  -97.69807                6
#
# ...

# %%
#Data types
df.dtypes
# Out:
# station_id          object
# Latitude           float64
# Longitude          float64
# Number of Bikes      int64
# name                object
# category_id          int64
# category_name       object
# review_count         int64
# distance             int64
# rating             float64
# address             object
# postcode             int64
# dtype: object

# %% [markdown]
# The bar chart below shows the distribution of the number of bikes accross different categories of restaurants

# %%
df.category_name.value_counts().nlargest(30).plot(kind='bar', figsize=(10,5))
plt.title("Number of bikes")
plt.ylabel("Number of bikes")
plt.xlabel("category_name");

# %% [markdown]
# That makes sense since we are explorint data for austin, TX in America

# %% [markdown]
# Histogram distribution of the numbere of bikes at each station

# %%
#Histogram of number of bikes
fig, ax =plt.subplots()
ax.hist(df['Number of Bikes'])
ax.set_title('histogram of Number of Bikes')
ax.set_xlabel('Number of bikes')
ax.set_ylabel('Counts')
plt.show()

# %% [markdown]
# Average rating by category using a bar plot

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='category_name', y='rating')
plt.title('Average Rating by Category')
plt.xlabel('Category')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

# %%
#relationship between the number of bikes and review counts using a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Number of Bikes', y='review_count')
plt.title('Number of Bikes vs. Review Count')
plt.xlabel('Number of Bikes')
plt.ylabel('Review Count')
plt.show()

# %%
#distributions of ratings using a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='rating')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.show()

# %%
#count of stations by category
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='category_name')
plt.title('Count of Stations by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
#Visualizing the relationship between number of bikes  and distance, to identify any potential correlations or patterns
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='distance', y='Number of Bikes')
plt.title('Scatter plot of Number of Bikes vs. Distance')
plt.xlabel('Distance')
plt.ylabel('Number of Bikes')
plt.show()

# %%
#use a box plot to display the distribution of number of bikes across different categories
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='category_name', y='Number of Bikes')
plt.title('Number of Bikes by Category')
plt.xlabel('Category')
plt.ylabel('Number of Bikes')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
import sqlite3
from sqlite3 import Error

# %%
def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("connection to sqlite DB sucessful")
    except Error as e:
        print(f"The error '{e}' occurred ")
        
    return connection

# %%
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query executed successfully")
    except Error as e:
        print(f"The error '{e}' occurred")

# %%
connection = create_connection("sm_app.sqlite")
# Out:
# connection to sqlite DB sucessful

# %%
create_citybikes_table = '''
CREATE TABLE IF NOT EXISTS citybikes (
    station_id TEXT PRIMARY KEY,
    station_name TEXT,
    longitude REAL,
    latitude REAL,
    Number_of_Bikes INTEGER
);
'''

# %%
execute_query(connection, create_citybikes_table)
# Out:
# Query executed successfully

# %%
create_foursquare_table = '''
CREATE TABLE IF NOT EXISTS foursquare (
    fsq_id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT,
    category_id INTEGER,
    category_name TEXT,
    postcode INTEGER,
    distance INTEGER,
    address TEXT,
    station_id TEXT,
    FOREIGN KEY (station_id) REFERENCES citybikes (station_id)
);
'''

# %%
execute_query(connection, create_foursquare_table)
# Out:
# Query executed successfully

# %%
create_yelp_table = '''
CREATE TABLE IF NOT EXISTS yelp (
    yelp_id INTEGER PRIMARY KEY AUTOINCREMENT,
    station_id TEXT
    name TEXT,
    category_id INTEGER,
    category_name TEXT,
    review_count INTEGER,
    rating REAL,
    postcode INTEGER,
    distance INTEGER
    address TEXT
    longitude REAL,
    latitude REAL,
    price TEXT,
    FOREIGN KEY (station_id) REFERENCES foursquare (station_id)
);
'''

# %%
execute_query(connection, create_yelp_table)
# Out:
# Query executed successfully

# %%
create_yelp_fsq_table = '''
CREATE TABLE IF NOT EXISTS yelp_fsq (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    station_id TEXT
    name TEXT,
    category_id INTEGER,
    category_name TEXT,
    review_count INTEGER,
    rating REAL,
    postcode INTEGER,
    distance INTEGER
    address TEXT
    FOREIGN KEY (station_id) REFERENCES citybikes (station_id)
);
'''

# %%
execute_query(connection, create_yelp_table)
# Out:
# Query executed successfully

# %%
import csv
import sqlite3

# %%
conn = sqlite3.connect('bike_stations.db')
cursor = conn.cursor()
cursor.execute()

# %% [markdown]
# Look at the data before and after the join to validate your data.
