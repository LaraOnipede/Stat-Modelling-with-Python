# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import os
import requests
import json
import pandas as pd

# %%
request_url = 'https://api.citybik.es/v2/networks'
header_dict = {'accept': 'application/JSON'}
response = requests.get(request_url, headers=header_dict)
response

#store response in a variable
citybikes = response.json()

print(citybikes)
# Out:
# {'networks': [{'company': ['ЗАО «СитиБайк»'], 'href': '/v2/networks/velobike-moscow', 'id': 'velobike-moscow', 'location': {'city': 'Moscow', 'country': 'RU', 'latitude': 55.75, 'longitude': 37.616667}, 'name': 'Velobike'}, {'company': ['Urban Infrastructure Partner'], 'href': '/v2/networks/baerum-bysykkel', 'id': 'baerum-bysykkel', 'location': {'city': 'Bærum', 'country': 'NO', 'latitude': 59.89455, 'longitude': 10.546343}, 'name': 'Bysykkel'}, {'company': ['Comunicare S.r.l.'], 'href': '/v2/networks/bicincitta-siena', 'id': 'bicincitta-siena', 'location': {'city': 'Siena', 'country': 'IT', 'latitude': 43.3186, 'longitude': 11.3306}, 'name': 'Bicincittà', 'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=202'}, {'company': ['Cyclopolis Systems'], 'href': '/v2/networks/cyclopolis-maroussi', 'id': 'cyclopolis-maroussi', 'location': {'city': 'Maroussi', 'country': 'GR', 'latitude': 38.0568722388, 'longitude': 23.8083299536}, 'name': 'Cyclopolis'}, {'company': ['Groundwork', 'Slough Borough Council', 'ITS'], 'href': '/v2/networks/cycle-hire-slough', 'id': 'cycle-hire-slough', 'location': {'city': 'Slough', 'country': 'GB', 'latitude': 51.51135, 'longitude': -0.591562}, 'name': 'Cycle Hire'}, {'company': ['Cyclopolis Systems'], 'href': '/v2/networks/cyclopolis-nafplio', 'id': 'cyclopolis-nafplio', 'location': {'city': 'Nafplio', 'country': 'GR', 'latitude': 37.5639397319, 'longitude': 22.8093402872}, 'name': 'Cyclopolis'}, {'company': ['Comunicare S.r.l.'], 'href': '/v2/networks/bicincitta-parco-dei-colli-di-bergamo', 'id': 'bicincitta-parco-dei-colli-di-bergamo', 'location': {'city': 'Parco dei Colli di Bergamo', 'country': 'IT', 'latitude': 45.72295637032245, 'longitude': 9.649230073016383}, 'name': 'Bicincittà', 'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=203'}, {'company': ['Cyclopolis Systems'], 'href': '/v2/networks/cyclopolis-aigialeia', 'id': 'cyclopolis-aigialeia', 'location': {'city': 'Aigialeia', 'country': 'GR', 'latitude': 38.2511101325, 'longitude': 22.0821570196}, 'name': 'Cyclopolis'}, {'company': ['Cyclopolis Systems'], 'href': '/v2/networks/cyclopolis-marathon', 'id': 'cyclopolis-marathon', 'location': {'city': 'Marathon', 'country': 'GR', 'latitude': 38.0855680022, 'longitude': 23.9776389963}, 'name': 'Cyclopolis'}, {'company': ['Comunicare S.r.l.'], 'href': '/v2/networks/bicincitta-mantova', 'id': 'bicincitta-mantova', 'location': {'city': 'Mantova', 'country': 'IT', 'latitude': 45.15866370764634, 'longitude': 10.783718973016335}, 'name': 'Bicincittà', 'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=204'}, {'company': ['Cyclopolis Systems'], 'href': '/v2/networks/cyclopolis-neasmyrni', 'id': 'cyclopolis-neasmyrni', 'location': {'city': 'Νea Smyrni', 'country': 'GR', 'latitude': 37.9381, 'longitude': 23.7126}, 'name': 'Cyclopolis'}, {'company': ['Cyclopolis Systems'], 'href': '/v2/networks/cyclopolis-moschatotavros', 'id': 'cyclopolis-moschatotavros', 'location': {'city': 'Μoschato-Tavros', 'country': 'GR', 'latitude': 37.9538991434, 'longitude': 23.6824746661}, 'name': 'Cyclopolis'}, {'company': ['Cyclopolis Systems'], 'href': '/v2/networks/cyclopolis-arxaiaolympia', 'id': 'cyclopolis-arxaiaolympia', 'location': {'city': 'Αrxaia Olympia', 'country': 'GR', 'latitude': 37.6419700934, 'longitude': 21.6247265179}, 'name': 'Cyclopolis'}, {'company': ['Cyclopolis Systems'], 'href': '/v2/networks/cyclopolis-kiato', 'id': 'cyclopolis-kiato', 'location': {'city': 'Kιato', 'country': 'GR', 'latitude': 38.0132674508, 'longitude': 22.7493819902}, 'name': 'Cyclopolis'}, {'company': ['Comunicare S.r.l.'], 'href': '/v2/networks/bicincitta-assemini', 'id': 'bicincitta-assemini', 'location': {'city': 'Assemini', 'country': 'IT', 'latitude': 39.28956306007679, 'longitude': 9.006601555294765}, 'name': 'Bicincittà', 'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=205'}, {'company': ['Cyclopolis Systems'], 'href': '/v2/networks/cyclopolis-rhodes', 'id': 'cyclopolis-rhodes', 'locatio ...

# %%
#print JSON response containing bike stations for Melbourne
city_id = "austin"
city_url = f'https://api.citybik.es/v2/networks/{city_id}'

response = requests.get(city_url)
austin_bikes = response.json()

print(austin_bikes)
# Out:
# {'network': {'company': ['BCycle, LLC'], 'gbfs_href': 'https://gbfs.bcycle.com/bcycle_austin/gbfs.json', 'href': '/v2/networks/austin', 'id': 'austin', 'location': {'city': 'Austin, TX', 'country': 'US', 'latitude': 30.26408, 'longitude': -97.74355}, 'name': 'Austin B-cycle', 'stations': [{'empty_slots': 9, 'extra': {'address': '400 Haywood Ave.', 'last_updated': 1688249025, 'renting': 1, 'returning': 1, 'uid': 'bcycle_austin_7186'}, 'free_bikes': 4, 'id': '01eedbec47378a4407f5a3fc4352fdf3', 'latitude': 30.25759, 'longitude': -97.74898, 'name': 'One Texas Center', 'timestamp': '2023-07-01T22:03:45.547000Z'}, {'empty_slots': 6, 'extra': {'address': '2711 Rio Grande Street', 'last_updated': 1688249025, 'renting': 1, 'returning': 1, 'uid': 'bcycle_austin_7189'}, 'free_bikes': 4, 'id': '57eb8e5d401aeabe67ff95e6f1f1f999', 'latitude': 30.29312, 'longitude': -97.74412, 'name': '28th/Rio Grande', 'timestamp': '2023-07-01T22:03:45.549000Z'}, {'empty_slots': 3, 'extra': {'address': '900 Pearl Street', 'last_updated': 1688249025, 'renting': 1, 'returning': 1, 'uid': 'bcycle_austin_7188'}, 'free_bikes': 10, 'id': 'ed95d8e12ad7c2ec3ff0b7dd0f4673f2', 'latitude': 30.2854, 'longitude': -97.74673, 'name': '22nd/Pearl', 'timestamp': '2023-07-01T22:03:45.550000Z'}, {'empty_slots': 9, 'extra': {'address': '672 Henderson Street', 'last_updated': 1688249025, 'renting': 1, 'returning': 1, 'uid': 'bcycle_austin_3685'}, 'free_bikes': 4, 'id': '8723bfa08ec83b133f6a9aeecd075f51', 'latitude': 30.27217, 'longitude': -97.75246, 'name': '9th/Henderson', 'timestamp': '2023-07-01T22:03:45.551000Z'}, {'empty_slots': 11, 'extra': {'address': '799 South Congress Avenue', 'last_updated': 1688249025, 'renting': 1, 'returning': 1, 'uid': 'bcycle_austin_4048'}, 'free_bikes': 1, 'id': '568256d098257d6e8433513638f5257b', 'latitude': 30.25495, 'longitude': -97.74755, 'name': 'South Congress @ Bouldin Creek', 'timestamp': '2023-07-01T22:03:45.552000Z'}, {'empty_slots': 6, 'extra': {'address': '1901 South Congress Ave.', 'last_updated': 1688249025, 'renting': 1, 'returning': 1, 'uid': 'bcycle_austin_7187'}, 'free_bikes': 4, 'id': 'a22287cc0ed65baf5d88b04916ad3f8e', 'latitude': 30.24496, 'longitude': -97.75127, 'name': 'South Congress/Mary', 'timestamp': '2023-07-01T22:03:45.552000Z'}, {'empty_slots': 7, 'extra': {'address': '401 W. 5th St.', 'last_updated': 1688249025, 'renting': 1, 'returning': 1, 'uid': 'bcycle_austin_3455'}, 'free_bikes': 7, 'id': '0071a519298ba811d05c62fcf03c39c6', 'latitude': 30.26727, 'longitude': -97.74718, 'name': '4th/Guadalupe @ Republic Square', 'timestamp': '2023-07-01T22:03:45.553000Z'}, {'empty_slots': 18, 'extra': {'address': '2007 University Ave. ', 'last_updated': 1688249025, 'renting': 1, 'returning': 1, 'uid': 'bcycle_austin_3797'}, 'free_bikes': 1, 'id': '127d6968e5b3b59b49005c0694d78815', 'latitude': 30.28354, 'longitude': -97.73953, 'name': '21st/University', 'timestamp': '2023-07-01T22:03:45.554000Z'}, {'empty_slots': 5, 'extra': {'address': '750 Lavaca Street', 'last_updated': 1688249025, 'renting': 1, 'returning': 1, 'uid': 'bcycle_austin_4047'}, 'free_bikes': 4, 'id': '5e3c201ddf35ac9a262e33a63ba0fda3', 'latitude': 30.27048, 'longitude': -97.74467, 'name': '8th/Lavaca', 'timestamp': '2023-07-01T22:03:45.555000Z'}, {'empty_slots': 17, 'extra': {'address': 'Presented by Graves Dougherty Hearon & Moody', 'last_updated': 1688249025, 'renting': 1, 'returning': 1, 'uid': 'bcycle_austin_2499'}, 'free_bikes': 1, 'id': '96840128a6de03042f986c91dcd38e00', 'latitude': 30.26476, 'longitude': -97.74678, 'name': '2nd/Lavaca @ City Hall', 'timestamp': '2023-07-01T22:03:45.555000Z'}, {'empty_slots': 15, 'extra': {'address': '200 E Dean Keeton St', 'last_updated': 1688249025, 'renting': 1, 'returning': 1, 'uid': 'bcycle_austin_2498'}, 'free_bikes': 2, 'id': '68f152a5c3e6e60cea8b8e1430e28906', 'latitude': 30.2896, 'longitude': -97.7366, 'name': 'Dean Keeton/Speedway', 'timestamp': '2023-07-01T22:03:45.556000Z'}, {'empty_slots': 12, 'extra': {'add ...

# %%
austin_bike_station = austin_bikes['network']['stations']

for station in austin_bike_station:
    latitude = station['latitude']
    longitude = station['longitude']
    num_bikes = station['free_bikes']
    
    print(f"Latitude: {latitude}, Longitude: {longitude}, Number of Bikes: {num_bikes}")
# Out:
# Latitude: 30.25759, Longitude: -97.74898, Number of Bikes: 4
# Latitude: 30.29312, Longitude: -97.74412, Number of Bikes: 4
# Latitude: 30.2854, Longitude: -97.74673, Number of Bikes: 10
# Latitude: 30.27217, Longitude: -97.75246, Number of Bikes: 4
# Latitude: 30.25495, Longitude: -97.74755, Number of Bikes: 1
# Latitude: 30.24496, Longitude: -97.75127, Number of Bikes: 4
# Latitude: 30.26727, Longitude: -97.74718, Number of Bikes: 7
# Latitude: 30.28354, Longitude: -97.73953, Number of Bikes: 1
# Latitude: 30.27048, Longitude: -97.74467, Number of Bikes: 4
# Latitude: 30.26476, Longitude: -97.74678, Number of Bikes: 1
# Latitude: 30.2896, Longitude: -97.7366, Number of Bikes: 2
# Latitude: 30.28928, Longitude: -97.733, Number of Bikes: 1
# Latitude: 30.25457, Longitude: -97.74258, Number of Bikes: 0
# Latitude: 30.29439, Longitude: -97.78375, Number of Bikes: 4
# Latitude: 30.27807, Longitude: -97.77272, Number of Bikes: 3
# Latitude: 30.26211, Longitude: -97.73875, Number of Bikes: 1
# Latitude: 30.24468, Longitude: -97.72311, Number of Bikes: 4
# Latitude: 30.25872, Longitude: -97.74614, Number of Bikes: 2
# Latitude: 30.26406, Longitude: -97.76385, Number of Bikes: 4
# Latitude: 30.26978, Longitude: -97.74224, Number of Bikes: 6
# Latitude: 30.26408, Longitude: -97.74355, Number of Bikes: 6
# Latitude: 30.25941, Longitude: -97.74971, Number of Bikes: 3
# Latitude: 30.2659, Longitude: -97.76822, Number of Bikes: 11
# Latitude: 30.26912, Longitude: -97.73986, Number of Bikes: 3
# Latitude: 30.25204, Longitude: -97.73459, Number of Bikes: 1
# Latitude: 30.2862, Longitude: -97.74516, Number of Bikes: 0
# Latitude: 30.26217, Longitude: -97.72743, Number of Bikes: 10
# Latitude: 30.25902, Longitude: -97.71479, Number of Bikes: 4
# Latitude: 30.28395, Longitude: -97.74198, Number of Bikes: 6
# Latitude: 30.26152, Longitude: -97.77258, Number of Bikes: 11
# Latitude: 30.26078, Longitude: -97.73808, Number of Bikes: 2
# Latitude: 30.24891, Longitude: -97.75019, Number of Bikes: 6
# Latitude: 30.27336, Longitude: -97.73805, Number of Bikes: 5
# Latitude: 30.2692, Longitude: -97.7535, Number of Bikes: 9
# Latitude: 30.26702, Longitude: -97.75476, Number of Bikes: 9
# Latitude: 30.26735, Longitude: -97.73933, Number of Bikes: 3
# Latitude: 30.27594, Longitude: -97.74733, Number of Bikes: 1
# Latitude: 30.25971, Longitude: -97.75346, Number of Bikes: 1
# Latitude: 30.26968, Longitude: -97.73074, Number of Bikes: 3
# Latitude: 30.26896, Longitude: -97.72843, Number of Bikes: 0
# Latitude: 30.25866, Longitude: -97.74895, Number of Bikes: 1
# Latitude: 30.2741, Longitude: -97.73666, Number of Bikes: 2
# Latitude: 30.2856, Longitude: -97.7335, Number of Bikes: 7
# Latitude: 30.26709, Longitude: -97.74947, Number of Bikes: 0
# Latitude: 30.25579, Longitude: -97.73982, Number of Bikes: 3
# Latitude: 30.25103, Longitude: -97.74926, Number of Bikes: 9
# Latitude: 30.28298, Longitude: -97.73731, Number of Bikes: 4
# Latitude: 30.28731, Longitude: -97.7465, Number of Bikes: 3
# Latitude: 30.2664, Longitude: -97.72164, Number of Bikes: 4
# Latitude: 30.26976, Longitude: -97.7184, Number of Bikes: 6
# Latitude: 30.27449, Longitude: -97.7699, Number of Bikes: 7
# Latitude: 30.27018, Longitude: -97.73531, Number of Bikes: 0
# Latitude: 30.27454, Longitude: -97.7645, Number of Bikes: 6
# Latitude: 30.2898, Longitude: -97.74041, Number of Bikes: 2
# Latitude: 30.26908, Longitude: -97.72429, Number of Bikes: 7
# Latitude: 30.26889, Longitude: -97.74525, Number of Bikes: 1
# Latitude: 30.25968, Longitude: -97.72321, Number of Bikes: 3
# Latitude: 30.25544, Longitude: -97.71677, Number of Bikes: 3
# Latitude: 30.29068, Longitude: -97.74292, Number of Bikes: 5
# Latitude: 30.262, Longitude: -97.76118, Number of Bikes: 4
# Latitude: 30.26455, Longitude: -97.73165, Number of Bikes: 4
# Latitude: 30.2678, Longitude: -97.75189, Number of Bikes: 1
# Latitude: 30.26437, Longitude: -97.75624, Number of Bikes: 6
# Latitude: 30.25222, Longitude: -97.74881, Number of Bikes: 5
# Latitude: 30.26854, Longitude: -97.73646, Number of Bikes: 4
# Latitude: 30.26452, Longitude: -97.77132, Number of Bikes: 6
# Latitude: 30.26332, Longitude: -97.74508, Number of Bikes: 8
# Latitude: 30.2627, Longitude: -97.7243, Number of Bikes: 5
# Latitude: 30.26428, Longitude: -97.74033, Number of Bikes: 3
# Latitude: 30.24269, Longitude: -97.7176, Number of Bikes: 2
# Latitude: 30.26438, Longitude: -97.73657, Number of Bikes: 0
# Latitude: 30.27924, Longitude: -97.74371, Number of Bikes: 6
# Latitude: 30.26822, Longitude: -97.74285, Number of Bikes: 3
# Latitude: 30.26032, Longitude: -97.71899, Number of Bikes: 5
# Latitude: 30.2563, Longitude: -97.71007, Number of Bikes: 9
# Latitude: 30.27041, Longitude: -97.75046, Number of Bikes: 4
# Latitude: 30.26634, Longitude: -97.74378, Number of Bikes: 5
# Latitude: 30.2726, Longitude: -97.74127, Number of Bikes: 14
# Latitude: 30.25212, Longitude: -97.69807, Number of Bikes: 6

# %%
austin_dict = {'Latitude': [], 'Longitude': [], 'Number of Bikes': []}
for station in austin_bike_station:
        latitude = station['latitude']
        longitude = station['longitude']
        num_bikes = station['free_bikes']
        
        austin_dict['Latitude'].append(latitude)
        austin_dict['Longitude'].append(longitude)
        austin_dict['Number of Bikes'].append(num_bikes)

# %%
austinbikes_df = pd.DataFrame(austin_dict)

# %%
austinbikes_df
# Out:
#     Latitude  Longitude  Number of Bikes
# 0   30.25759  -97.74898                4
# 1   30.29312  -97.74412                4
# 2   30.28540  -97.74673               10
# 3   30.27217  -97.75246                4
# 4   30.25495  -97.74755                1
# ..       ...        ...              ...
# 74  30.25630  -97.71007                9
# 75  30.27041  -97.75046                4
# 76  30.26634  -97.74378                5
# 77  30.27260  -97.74127               14
# 78  30.25212  -97.69807                6
#
# [79 rows x 3 columns]

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
import os

# %%
#set the keys
#foursquare_id = os.environ["FOURSQUAREAPIID"] 
#foursquare_secret = os.environ["FOURSQUAREAPISECRET"]
foursquare_api_key = os.environ['FOURSQUAREAPIKEY2']
foursquare_api_keyå
# Out:
# 'fsq3JQKwJl7WkF9UliuPny8nyJNMro/pGp/qkRoYHXvZOE0='

# %%
URL = "https://api.foursquare.com/v3/places/search" 

params = {
            "query": "restaurant",
            "ll" : "30.25759,-97.74898",
            "open_now": "true",
            "radius": "1000"
        }
            
header_dict = {
    "Accept": "application/JSON",
    "Authorization": foursquare_api_key 
}
response = requests.request("GET", URL, params=params, headers= header_dict)
print(response.text)
# Out:
# {"results":[{"fsq_id":"4a4a4d21f964a520abab1fe3","categories":[{"id":13031,"name":"Burger Joint","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/burger_","suffix":".png"}},{"id":13068,"name":"American Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}},{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":213,"geocodes":{"drop_off":{"latitude":30.258682,"longitude":-97.750966},"main":{"latitude":30.258428,"longitude":-97.751056},"roof":{"latitude":30.258428,"longitude":-97.751056}},"link":"/v3/places/4a4a4d21f964a520abab1fe3","location":{"address":"603 Barton Springs Rd","census_block":"484530013111009","country":"US","cross_street":"at S. 1st St.","dma":"Austin","formatted_address":"603 Barton Springs Rd (at S. 1st St.), Austin, TX 78704","locality":"Austin","postcode":"78704","region":"TX"},"name":"Sandy's Hamburgers","related_places":{},"timezone":"America/Chicago"},{"fsq_id":"4a259766f964a5206f7e1fe3","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13303,"name":"Mexican Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/mexican_","suffix":".png"}}],"chains":[{"id":"c14ce7bc-95f4-4e16-a088-8e55ab737da8","name":"Freebirds World Burrito"}],"distance":270,"geocodes":{"main":{"latitude":30.255835,"longitude":-97.746627},"roof":{"latitude":30.255835,"longitude":-97.746627}},"link":"/v3/places/4a259766f964a5206f7e1fe3","location":{"address":"515 S Congress Ave","census_block":"484530014013000","country":"US","cross_street":"at E Riverside Dr","dma":"Austin","formatted_address":"515 S Congress Ave (at E Riverside Dr), Austin, TX 78704","locality":"Austin","postcode":"78704","region":"TX"},"name":"Freebirds World Burrito","related_places":{},"timezone":"America/Chicago"},{"fsq_id":"49e98f83f964a520fe651fe3","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[{"id":"1217b74d-411f-4283-a24a-39b916ed964d","name":"Whataburger"}],"distance":172,"geocodes":{"main":{"latitude":30.258078,"longitude":-97.750765},"roof":{"latitude":30.258078,"longitude":-97.750765}},"link":"/v3/places/49e98f83f964a520fe651fe3","location":{"address":"601 Barton Springs Rd","census_block":"484530013111009","country":"US","cross_street":"S. 1st St.","dma":"Austin","formatted_address":"601 Barton Springs Rd (S. 1st St.), Austin, TX 78704","locality":"Austin","postcode":"78704","region":"TX"},"name":"Whataburger","related_places":{},"timezone":"America/Chicago"},{"fsq_id":"5f5c5bcaaf65ef27d8d6b4d5","categories":[{"id":13000,"name":"Dining and Drinking","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":426,"geocodes":{"main":{"latitude":30.25347,"longitude":-97.747892},"roof":{"latitude":30.25347,"longitude":-97.747892}},"link":"/v3/places/5f5c5bcaaf65ef27d8d6b4d5","location":{"address":"1011 S Congress Ave","census_block":"484530014013001","country":"US","cross_street":"","dma":"Austin","formatted_address":"1011 S Congress Ave, Austin, TX 78704","locality":"Austin","postcode":"78704","region":"TX"},"name":"Aba Austin","related_places":{},"timezone":"America/Chicago"},{"fsq_id":"4a7c784bf964a520b4ec1fe3","categories":[{"id":13334,"name":"Sandwich Spot","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/deli_","suffix":".png"}}],"chains":[],"distance":440,"geocodes":{"main":{"latitude":30.255095,"longitude":-97.745223},"roof":{"latitude":30.255095,"longitude":-97.745223}},"link":"/v3/places/4a7c784bf964a520b4ec1fe3","location":{"address":"201 E Riverside Dr","census_block":"484530014013000","country":"US","cross_street":"btw Congress and Newning","dma":"Austin","formatted_address":"201 E Riverside  ...

# %%
res_json1 =response.json()
res_json1
# Out:
# {'results': [{'fsq_id': '4a4a4d21f964a520abab1fe3',
#    'categories': [{'id': 13031,
#      'name': 'Burger Joint',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'}},
#     {'id': 13068,
#      'name': 'American Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13145,
#      'name': 'Fast Food Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 213,
#    'geocodes': {'drop_off': {'latitude': 30.258682, 'longitude': -97.750966},
#     'main': {'latitude': 30.258428, 'longitude': -97.751056},
#     'roof': {'latitude': 30.258428, 'longitude': -97.751056}},
#    'link': '/v3/places/4a4a4d21f964a520abab1fe3',
#    'location': {'address': '603 Barton Springs Rd',
#     'census_block': '484530013111009',
#     'country': 'US',
#     'cross_street': 'at S. 1st St.',
#     'dma': 'Austin',
#     'formatted_address': '603 Barton Springs Rd (at S. 1st St.), Austin, TX 78704',
#     'locality': 'Austin',
#     'postcode': '78704',
#     'region': 'TX'},
#    'name': "Sandy's Hamburgers",
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4a259766f964a5206f7e1fe3',
#    'categories': [{'id': 13145,
#      'name': 'Fast Food Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#       'suffix': '.png'}},
#     {'id': 13303,
#      'name': 'Mexican Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'c14ce7bc-95f4-4e16-a088-8e55ab737da8',
#      'name': 'Freebirds World Burrito'}],
#    'distance': 270,
#    'geocodes': {'main': {'latitude': 30.255835, 'longitude': -97.746627},
#     'roof': {'latitude': 30.255835, 'longitude': -97.746627}},
#    'link': '/v3/places/4a259766f964a5206f7e1fe3',
#    'location': {'address': '515 S Congress Ave',
#     'census_block': '484530014013000',
#     'country': 'US',
#     'cross_street': 'at E Riverside Dr',
#     'dma': 'Austin',
#     'formatted_address': '515 S Congress Ave (at E Riverside Dr), Austin, TX 78704',
#     'locality': 'Austin',
#     'postcode': '78704',
#     'region': 'TX'},
#    'name': 'Freebirds World Burrito',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '49e98f83f964a520fe651fe3',
#    'categories': [{'id': 13145,
#      'name': 'Fast Food Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#       'suffix': '.png'}}],
#    'chains': [{'id': '1217b74d-411f-4283-a24a-39b916ed964d',
#      'name': 'Whataburger'}],
#    'distance': 172,
#    'geocodes': {'main': {'latitude': 30.258078, 'longitude': -97.750765},
#     'roof': {'latitude': 30.258078, 'longitude': -97.750765}},
#    'link': '/v3/places/49e98f83f964a520fe651fe3',
#    'location': {'address': '601 Barton Springs Rd',
#     'census_block': '484530013111009',
#     'country': 'US',
#     'cross_street': 'S. 1st St.',
#     'dma': 'Austin',
#     'formatted_address': '601 Barton Springs Rd (S. 1st St.), Austin, TX 78704',
#     'locality': 'Austin',
#     'postcode': '78704',
#     'region': 'TX'},
#    'name': 'Whataburger',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '5f5c5bcaaf65ef27d8d6b4d5',
#    'categories': [{'id': 13000,
#      'name': 'Dining and Drinking',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 426,
#    'geocodes': {'main': {'latitude': 30.25347, 'longitude': -97.747892},
#     'roof': {'latitude': 30.25347, 'longitude': -97.747892}},
#    'link': '/v3/places/5f5c5bcaaf65ef27d8d6b4d5',
#    'location': {'address': '1011 S Congress Ave',
#     'census_block': '484530014013001',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Austin',
#     'formatted_address': '1011 S Congress Ave, Austin, TX 78704',
#     'locality': 'Austin',
#     'postcode': '78704',
#     'region': 'TX'},
#    'name': 'Aba Austin',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4a7c784bf964a520b4ec1fe3',
#    'categories': [{'id': 13334,
#      'name': 'Sandwich Spot',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 440,
#    'geocodes': {'main': {'latitude': 30.255095, 'longitude': -97.745223},
#     'roof': {'latitude': 30.255095, 'longitude': -97.745223}},
#    'link': '/v3/places/4a7c784bf964a520b4ec1fe3',
#    'location': {'address': '201 E Riverside Dr',
#     'census_block': '484530014013000',
#     'country': 'US',
#     'cross_street': 'btw Congress and Newning',
#     'dma': 'Austin',
#     'formatted_address': '201 E Riverside Dr (btw Congress and Newning), Austin, TX 78704',
#     'locality': 'Austin',
#     'postcode': '78704',
#     'region': 'TX'},
#    'name': 'Thundercloud Sub',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '5f15f247d61f0c2339830028',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'e9b6ff79-62b5-4a0b-9ef6-b9bf15f3b53f',
#      'name': 'sweetgreen'}],
#    'distance': 424,
#    'geocodes': {'main': {'latitude': 30.253746, 'longitude': -97.74709},
#     'roof': {'latitude': 30.253746, 'longitude': -97.74709}},
#    'link': '/v3/places/5f15f247d61f0c2339830028',
#    'location': {'address': '1007 S Congress Ave',
#     'census_block': '484530014013001',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Austin',
#     'formatted_address': '1007 S Congress Ave, Austin, TX 78704',
#     'locality': 'Austin',
#     'postcode': '78704',
#     'region': 'TX'},
#    'name': 'sweetgreen',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '59f3780648b04e7788d4e848',
#    'categories': [{'id': 13009,
#      'name': 'Cocktail Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'}},
#     {'id': 13306,
#      'name': 'Taco Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#       'suffix': '.png'}},
#     {'id': 13334,
#      'name': 'Sandwich Spot',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 230,
#    'geocodes': {'main': {'latitude': 30.258617, 'longitude': -97.746954},
#     'roof': {'latitude': 30.258617, 'longitude': -97.746954}},
#    'link': '/v3/places/59f3780648b04e7788d4e848',
#    'location': {'address': '300 S Congress Ave',
#     'census_block': '484530013111008',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Austin',
#     'formatted_address': '300 S Congress Ave, Austin, TX 78704',
#     'locality': 'Austin',
#     'postcode': '78704',
#     'region': 'TX'},
#    'name': 'Soco Bar & Bites',
#    'related_places': {'parent': {'fsq_id': '4b9b22dcf964a52061f535e3',
#      'name': 'Embassy Suites by Hilton Austin Downtown South Congress'}},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '6067e0f731dd1376bcfd6aaf',
#    'categories': [{'id': 13000,
#      'name': 'Dining and Drinking',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 240,
#    'geocodes': {'main': {'latitude': 30.257194, 'longitude': -97.746416},
#     'roof': {'latitude': 30.257194, 'longitude': -97.746416}},
#    'link': '/v3/places/6067e0f731dd1376bcfd6aaf',
#    'location': {'address': '343 S Congress Ave',
#     'census_block': '484530014012000',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Austin',
#     'formatted_address': '343 S Congress Ave, Austin, TX 78704',
#     'locality': 'Austin',
#     'postcode': '78704',
#     'region': 'TX'},
#    'name': 'AustinMed Break',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '533efc4d498e3775c831b2ee',
#    'categories': [{'id': 13026,
#      'name': 'BBQ Joint',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 626,
#    'geocodes': {'drop_off': {'latitude': 30.259769, 'longitude': -97.754879},
#     'main': {'latitude': 30.259649, 'longitude': -97.754801},
#     'roof': {'latitude': 30.259649, 'longitude': -97.754801}},
#    'link': '/v3/places/533efc4d498e3775c831b2ee',
#    'location': {'address': '1003 Barton Springs Rd',
#     'census_block': '484530013123000',
#     'country': 'US',
#     'cross_street': 'btwn Dawson Rd & Bouldin Ave',
#     'dma': 'Austin',
#     'formatted_address': '1003 Barton Springs Rd (btwn Dawson Rd & Bouldin Ave), Austin, TX 78704',
#     'locality': 'Austin',
#     'postcode': '78704',
#     'region': 'TX'},
#    'name': "Terry Black's Barbecue",
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4e1f95f5922e11c00663c2f2',
#    'categories': [{'id': 13303,
#      'name': 'Mexican Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 692,
#    'geocodes': {'drop_off': {'latitude': 30.260275, 'longitude': -97.75555},
#     'main': {'latitude': 30.260002, 'longitude': -97.755643},
#     'roof': {'latitude': 30.260002, 'longitude': -97.755643}},
#    'link': '/v3/places/4e1f95f5922e11c00663c2f2',
#    'location': {'address': '1025 Barton Springs Rd',
#     'census_block': '484530013123000',
#     'country': 'US',
#     'cross_street': 'at Dawson Rd.',
#     'dma': 'Austin',
#     'formatted_address': '1025 Barton Springs Rd (at Dawson Rd.), Austin, TX 78704',
#     'locality': 'Austin',
#     'postcode': '78704',
#     'region': 'TX'},
#    'name': 'El Alma',
#    'related_places': {},
#    'timezone': 'America/Chicago'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 30.25759,
#      'longitude': -97.74898},
#     'radius': 1000}}}}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
# for citybikes DataFtame 'austinbikes_df' with station data
# query foursquareAPi for data on austinbikes 
foursquare_api_key = os.environ['FOURSQUAREAPIKEY2']
foursquare_api_key


URL = "https://api.foursquare.com/v3/places/search"

header_dict = {
    "Accept": "application/json",
    "Authorization": foursquare_api_key
}

for index, row in austinbikes_df.iterrows():
    # Extract station coordinates
    lat = row['Latitude']
    lng = row['Longitude']
    location = f"{lat},{lng}"

    # Set parameters for Foursquare API request
    params = {
        "query": "restaurant",
        "ll": location,
        "radius": "1000"
    }
            
    response = requests.request("GET", URL, params=params, headers= header_dict)
    res_json2 = response.json()

# %%
res_json2
# Out:
# {'results': [{'fsq_id': '4aa83af3f964a520415020e3',
#    'categories': [{'id': 13148,
#      'name': 'French Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 264,
#    'geocodes': {'main': {'latitude': 30.253272, 'longitude': -97.700578},
#     'roof': {'latitude': 30.253272, 'longitude': -97.700578}},
#    'link': '/v3/places/4aa83af3f964a520415020e3',
#    'location': {'address': '4710 E 5th St',
#     'census_block': '484530021112024',
#     'country': 'US',
#     'dma': 'Austin',
#     'formatted_address': '4710 E 5th St, Austin, TX 78702',
#     'locality': 'Austin',
#     'postcode': '78702',
#     'region': 'TX'},
#    'name': "Justine's Brasserie",
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '53075b12498e717329657cd5',
#    'categories': [{'id': 13049,
#      'name': 'Diner',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#       'suffix': '.png'}},
#     {'id': 13068,
#      'name': 'American Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13095,
#      'name': 'Cajun and Creole Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 367,
#    'geocodes': {'main': {'latitude': 30.251427, 'longitude': -97.701832},
#     'roof': {'latitude': 30.251427, 'longitude': -97.701832}},
#    'link': '/v3/places/53075b12498e717329657cd5',
#    'location': {'address': '4827 E Cesar Chavez St',
#     'census_block': '484530021112022',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Austin',
#     'formatted_address': '4827 E Cesar Chavez St, Austin, TX 78702',
#     'locality': 'Austin',
#     'postcode': '78702',
#     'region': 'TX'},
#    'name': 'Sawyer & Co',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '608de6a21cd0812099c55137',
#    'categories': [{'id': 13009,
#      'name': 'Cocktail Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'}},
#     {'id': 13025,
#      'name': 'Wine Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#       'suffix': '.png'}},
#     {'id': 13306,
#      'name': 'Taco Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 400,
#    'geocodes': {'drop_off': {'latitude': 30.251714, 'longitude': -97.702145},
#     'main': {'latitude': 30.251505, 'longitude': -97.702165},
#     'roof': {'latitude': 30.251505, 'longitude': -97.702165}},
#    'link': '/v3/places/608de6a21cd0812099c55137',
#    'location': {'address': '4715 E Cesar Chavez St',
#     'census_block': '484530021112022',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Austin',
#     'formatted_address': '4715 E Cesar Chavez St, Austin, TX 78702',
#     'locality': 'Austin',
#     'postcode': '78702',
#     'region': 'TX'},
#    'name': 'De Nada Cantina',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '5718ed04cd104c1e9621e321',
#    'categories': [{'id': 13054,
#      'name': 'Food Truck',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 137,
#    'geocodes': {'main': {'latitude': 30.251055, 'longitude': -97.699543},
#     'roof': {'latitude': 30.251055, 'longitude': -97.699543}},
#    'link': '/v3/places/5718ed04cd104c1e9621e321',
#    'location': {'address': '5011 E Cesar Chavez St',
#     'census_block': '484530021112022',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Austin',
#     'formatted_address': '5011 E Cesar Chavez St, Austin, TX 78702',
#     'locality': 'Austin',
#     'postcode': '78702',
#     'region': 'TX'},
#    'name': 'Taqueria La Chilanga',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '5e3dae07323e870008e67e36',
#    'categories': [{'id': 13026,
#      'name': 'BBQ Joint',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 239,
#    'geocodes': {'main': {'latitude': 30.254275, 'longitude': -97.697662},
#     'roof': {'latitude': 30.254275, 'longitude': -97.697662}},
#    'link': '/v3/places/5e3dae07323e870008e67e36',
#    'location': {'address': '5012 E 7th St',
#     'census_block': '484530021112025',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Austin',
#     'formatted_address': '5012 E 7th St, Austin, TX 78702',
#     'locality': 'Austin',
#     'postcode': '78702',
#     'region': 'TX'},
#    'name': 'JNL Barbecue',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '54cb9b12498e0db58a3cbc74',
#    'categories': [{'id': 13303,
#      'name': 'Mexican Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 651,
#    'geocodes': {'drop_off': {'latitude': 30.256609, 'longitude': -97.702522},
#     'main': {'latitude': 30.256837, 'longitude': -97.702369},
#     'roof': {'latitude': 30.256837, 'longitude': -97.702369}},
#    'link': '/v3/places/54cb9b12498e0db58a3cbc74',
#    'location': {'address': '3518 E 7th St',
#     'census_block': '484530009021021',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Austin',
#     'formatted_address': '3518 E 7th St, Austin, TX 78702',
#     'locality': 'Austin',
#     'postcode': '78702',
#     'region': 'TX'},
#    'name': "Beto's Mexican Restaurant",
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '50730994e4b0d53d2251fbdd',
#    'categories': [{'id': 13307,
#      'name': 'Tex-Mex Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 715,
#    'geocodes': {'main': {'latitude': 30.256182, 'longitude': -97.692672},
#     'roof': {'latitude': 30.256182, 'longitude': -97.692672}},
#    'link': '/v3/places/50730994e4b0d53d2251fbdd',
#    'location': {'address': '817 Airport Blvd',
#     'census_block': '484530021112005',
#     'country': 'US',
#     'cross_street': 'Glissman Rd',
#     'dma': 'Austin',
#     'formatted_address': '817 Airport Blvd (Glissman Rd), Austin, TX 78702',
#     'locality': 'Austin',
#     'postcode': '78702',
#     'region': 'TX'},
#    'name': 'El Secreto Dela Abuela Mexican Restauran',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4a42d3dbf964a52045a61fe3',
#    'categories': [{'id': 13031,
#      'name': 'Burger Joint',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'}},
#     {'id': 13068,
#      'name': 'American Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13145,
#      'name': 'Fast Food Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 808,
#    'geocodes': {'main': {'latitude': 30.258417, 'longitude': -97.693842},
#     'roof': {'latitude': 30.258417, 'longitude': -97.693842}},
#    'link': '/v3/places/4a42d3dbf964a52045a61fe3',
#    'location': {'address': '844 Airport Blvd',
#     'census_block': '484530021112006',
#     'country': 'US',
#     'cross_street': 'Shady Ln',
#     'dma': 'Austin',
#     'formatted_address': '844 Airport Blvd (Shady Ln), Austin, TX 78702',
#     'locality': 'Austin',
#     'postcode': '78702',
#     'region': 'TX'},
#    'name': "Dan's Hamburgers - Austin",
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4e8f140fe5facbf44508bf89',
#    'categories': [{'id': 17067,
#      'name': 'Fruit and Vegetable Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}},
#     {'id': 17069,
#      'name': 'Grocery Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 500,
#    'geocodes': {'main': {'latitude': 30.255994, 'longitude': -97.700706},
#     'roof': {'latitude': 30.255994, 'longitude': -97.700706}},
#    'link': '/v3/places/4e8f140fe5facbf44508bf89',
#    'location': {'address': '4618 E 7th St',
#     'census_block': '484530021112025',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Austin',
#     'formatted_address': '4618 E 7th St, Austin, TX 78702',
#     'locality': 'Austin',
#     'postcode': '78702',
#     'region': 'TX'},
#    'name': 'Segovia Produce Company',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '53101130498e3fd9c77d4135',
#    'categories': [{'id': 13068,
#      'name': 'American Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13314,
#      'name': 'New American Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 891,
#    'geocodes': {'main': {'latitude': 30.251503, 'longitude': -97.707409},
#     'roof': {'latitude': 30.251503, 'longitude': -97.707409}},
#    'link': '/v3/places/53101130498e3fd9c77d4135',
#    'location': {'address': '3235 E Cesar Chavez St',
#     'census_block': '484530010003000',
#     'country': 'US',
#     'cross_street': 'Tillery',
#     'dma': 'Austin',
#     'formatted_address': '3235 E Cesar Chavez St (Tillery), Austin, TX 78702',
#     'locality': 'Austin',
#     'postcode': '78702',
#     'region': 'TX'},
#    'name': "Jacoby's Restaurant & Mercantile",
#    'related_places': {},
#    'timezone': 'America/Chicago'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 30.25212,
#      'longitude': -97.69807},
#     'radius': 1000}}}}

# %%
for i in res_json2["results"]:
    for category in i["categories"]:
        print(category["name"])
# Out:
# French Restaurant
# Diner
# American Restaurant
# Cajun and Creole Restaurant
# Cocktail Bar
# Wine Bar
# Taco Restaurant
# Food Truck
# BBQ Joint
# Mexican Restaurant
# Tex-Mex Restaurant
# Burger Joint
# American Restaurant
# Fast Food Restaurant
# Fruit and Vegetable Store
# Grocery Store
# American Restaurant
# New American Restaurant

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
import pandas as pd
import requests

# Assuming you have a dataframe called 'austinbikes_df' with station data
foursquare_api_key = os.environ['FOURSQUAREAPIKEY2']

URL = "https://api.foursquare.com/v3/places/search"

header_dict = {
    "Accept": "application/json",
    "Authorization": foursquare_api_key
}

a = []
b = []
c = []
d = []
e = []
f = []

for index, row in austinbikes_df.iterrows():
    # Extract station coordinates
    lat = row['Latitude']
    lng = row['Longitude']
    location = f"{lat},{lng}"

    # Set parameters for Foursquare API request
    params = {
        "query": "restaurant",
        "ll": location,
        "radius": "1000"
    }

    response = requests.get(URL, params=params, headers=header_dict)
    res_json = response.json()
    try:
        for i in res_json["results"]:
            a.append(i.get("name", None))  # Append name to 'a' list
            if "address" in i.get("location", {}):
                b.append(i["location"]["address"])  # Append address to 'b' list
            else:
                b.append(None)
            if "categories" in i:
                c.append(i["categories"][0].get("id", None))  # Append category ID to 'c' list
                d.append(i["categories"][0].get("name", None))  # Append category name to 'd' list
            else:
                c.append(None)
                d.append(None)
            e.append(i["location"].get("postcode", None))  # Append postcode to 'e' list
            f.append(i.get("distance", None))  # Append distance to 'f' list
    except:
        pass

foursquare_df = pd.DataFrame({"name": a, "address": b, "category_id": c, "category_name": d, "postcode": e, "distance": f})

# Print or do further processing with the dataframe 'df'
print(foursquare_df)
# Out:
#                                          name                 address  \
# 0                          Sandy's Hamburgers   603 Barton Springs Rd
# 1                     Freebirds World Burrito      515 S Congress Ave
# 2                                  Taco Joint      134 E Riverside Dr
# 3                                 Whataburger   601 Barton Springs Rd
# 4                                  Aba Austin     1011 S Congress Ave
# ..                                        ...                     ...
# 773                 Beto's Mexican Restaurant           3518 E 7th St
# 774  El Secreto Dela Abuela Mexican Restauran        817 Airport Blvd
# 775                 Dan's Hamburgers - Austin        844 Airport Blvd
# 776                   Segovia Produce Company           4618 E 7th St
# 777          Jacoby's Restaurant & Mercantile  3235 E Cesar Chavez St
#
#      category_id              category_name postcode  distance
# 0          13031               Burger Joint    78704       213
# 1          13145       Fast Food Restaurant    78704       270
# 2          13145       Fast Food Restaurant    78704       354
# 3          13145       Fast Food Restaurant    78704       172
# 4          13000        Dining and Drinking    78704       426
# ..           ...                        ...      ...       ...
# 773        13303         Mexican Restaurant    78702       651
# 774        13307         Tex-Mex Restaurant    78702       715
# 775        13031               Burger Joint    78702       808
# 776        17067  Fruit and Vegetable Store    78702       500
# 777        13068        American Restaurant    78702       891
#
# [778 rows x 6 columns]

# %%
foursquare_df.head(20)
# Out:
#                        name                address  category_id  \
# 0        Sandy's Hamburgers  603 Barton Springs Rd        13031
# 1   Freebirds World Burrito     515 S Congress Ave        13145
# 2                Taco Joint     134 E Riverside Dr        13145
# 3               Whataburger  601 Barton Springs Rd        13145
# 4                Aba Austin    1011 S Congress Ave        13000
# 5          Thundercloud Sub     201 E Riverside Dr        13334
# 6                sweetgreen    1007 S Congress Ave        13065
# 7          Soco Bar & Bites     300 S Congress Ave        13009
# 8                 Two Hands    1011 S Congress Ave        13034
# 9           AustinMed Break     343 S Congress Ave        13000
# 10           Torchy’S Tacos      2801 Guadalupe St        13145
# 11               Halal Bros      2712 Guadalupe St        13191
# 12     Dirty Martin's Place      2808 Guadalupe St        13031
# 13      Cabo Bob's Burritos     2828 Rio Grande St        13145
# 14              Whataburger      2800 Guadalupe St        13145
# 15    Counter Cafe - Austin          603 W 29th St        13034
# 16                   Arlo's          2908 Fruth St        13031
# 17                  Sip Pho          512 W 29th St        13347
# 18         Kerbey Lane Cafe      2606 Guadalupe St        13034
# 19          In-N-Out Burger      2700 Guadalupe St        13031
#
#            category_name postcode  distance
# 0           Burger Joint    78704       213
# 1   Fast Food Restaurant    78704       270
# 2   Fast Food Restaurant    78704       354
# 3   Fast Food Restaurant    78704       172
# 4    Dining and Drinking    78704       426
# 5          Sandwich Spot    78704       440
# 6             Restaurant    78704       424
# 7           Cocktail Bar    78704       230
# 8                   Café    78704       472
# 9    Dining and Drinking    78704       240
# 10  Fast Food Restaurant    78705       238
# 11      Halal Restaurant    78705       243
# 12          Burger Joint    78705       196
# 13  Fast Food Restaurant    78705       304
# 14  Fast Food Restaurant    78705       191
# 15                  Café    78705       262
# 16          Burger Joint    78705       284
# 17      Tapas Restaurant    78705       315
# 18                  Café    78705       328
# 19          Burger Joint    78705       266

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
import os
import requests

yelp_api_key = os.environ['YELP_API_KEY']

URL = "https://api.yelp.com/v3/businesses/search" 

params = {
    "term": "restaurant",
    "location": "Austin, TX",
    "open_now": "true",
    "radius": "1000"
}

header_dict = {
    "Accept": "application/JSON",
    "Authorization": "Bearer " + yelp_api_key
}

response = requests.get(URL, params=params, headers=header_dict)
print(response.text)
# Out:
# {"businesses": [{"id": "sdoXMx2zQmzmuLsdNAte7A", "alias": "little-house-austin", "name": "Little House", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/cZ8rHEcySwvsilbprBThTA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/little-house-austin?adjust_creative=Cj25br551HFlGRXjoFsHcQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Cj25br551HFlGRXjoFsHcQ", "review_count": 10, "categories": [{"alias": "foodtrucks", "title": "Food Trucks"}, {"alias": "fishnchips", "title": "Fish & Chips"}], "rating": 4.0, "coordinates": {"latitude": 30.31106, "longitude": -97.74289}, "transactions": ["delivery"], "price": "$$", "location": {"address1": "4112 Medical Pkwy", "address2": null, "address3": "", "city": "Austin", "zip_code": "78756", "country": "US", "state": "TX", "display_address": ["4112 Medical Pkwy", "Austin, TX 78756"]}, "phone": "+15124526258", "display_phone": "(512) 452-6258", "distance": 827.3035650148915}, {"id": "sOUbbSAwhfdZoGnSZqOlWw", "alias": "p-terrys-burger-stand-austin-8", "name": "P. Terry's Burger Stand", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/1jEt86AJDyUTXFSs7ayJVw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/p-terrys-burger-stand-austin-8?adjust_creative=Cj25br551HFlGRXjoFsHcQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Cj25br551HFlGRXjoFsHcQ", "review_count": 493, "categories": [{"alias": "burgers", "title": "Burgers"}, {"alias": "hotdogs", "title": "Fast Food"}], "rating": 3.5, "coordinates": {"latitude": 30.3017492, "longitude": -97.7449168}, "transactions": ["delivery"], "price": "$", "location": {"address1": "3303 N Lamar Blvd", "address2": "", "address3": "", "city": "Austin", "zip_code": "78705", "country": "US", "state": "TX", "display_address": ["3303 N Lamar Blvd", "Austin, TX 78705"]}, "phone": "+15123719975", "display_phone": "(512) 371-9975", "distance": 918.7454780609215}], "total": 2, "region": {"center": {"longitude": -97.7508544921875, "latitude": 30.308229134701293}}}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
yelp_json = response.json()
yelp_json
yelp_json["businesses"]
# Out:
# [{'id': 'sdoXMx2zQmzmuLsdNAte7A',
#   'alias': 'little-house-austin',
#   'name': 'Little House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cZ8rHEcySwvsilbprBThTA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/little-house-austin?adjust_creative=Cj25br551HFlGRXjoFsHcQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Cj25br551HFlGRXjoFsHcQ',
#   'review_count': 10,
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#    {'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.31106, 'longitude': -97.74289},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4112 Medical Pkwy',
#    'address2': None,
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78756',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['4112 Medical Pkwy', 'Austin, TX 78756']},
#   'phone': '+15124526258',
#   'display_phone': '(512) 452-6258',
#   'distance': 827.3035650148915},
#  {'id': 'sOUbbSAwhfdZoGnSZqOlWw',
#   'alias': 'p-terrys-burger-stand-austin-8',
#   'name': "P. Terry's Burger Stand",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1jEt86AJDyUTXFSs7ayJVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/p-terrys-burger-stand-austin-8?adjust_creative=Cj25br551HFlGRXjoFsHcQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Cj25br551HFlGRXjoFsHcQ',
#   'review_count': 493,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 30.3017492, 'longitude': -97.7449168},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '3303 N Lamar Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78705',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3303 N Lamar Blvd', 'Austin, TX 78705']},
#   'phone': '+15123719975',
#   'display_phone': '(512) 371-9975',
#   'distance': 918.7454780609215}]

# %%
for i in yelp_json["businesses"]:
   # print(i["name"]) #this prints each of the dict
    #print(i["review_count"])
   # print(i["rating"])
    print(i["transactions"])
    print(i["categories"][1]["alias"])
    # print(i["location"]["country"])
    # print(i["location"]["region"])
# Out:
# ['delivery']
# fishnchips
# ['delivery']
# hotdogs

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
import pandas as pd
import requests
import os

# Assuming you have a dataframe called 'austinbikes_df' with station data
yelp_api_key = os.environ['YELP_API_KEY']

URL = "https://api.yelp.com/v3/businesses/search"

header_dict = {
    "Accept": "application/JSON",
    "Authorization": "Bearer " + yelp_api_key
}

a = []
b = []
c = []
d = []
e = []
f = []

for index, row in austinbikes_df.iterrows():
    # Extract station coordinates
    lat = row['Latitude']
    lng = row['Longitude']
    location = f"{lat},{lng}"

    # Set parameters for Yelp API request
    params = {
        "term": "restaurant",
        "location": location,
        "radius": "1000"
    }

    response = requests.get(URL, params=params, headers=header_dict)
    res_json = response.json()

    try:
        for i in res_json["businesses"]:
            a.append(i.get("name", None))  # Append name to 'a' list
            if "location" in i and "address1" in i["location"]:
                b.append(i["location"]["address1"])  # Append address to 'b' list
            else:
                b.append(None)
            c.append(i.get("transactions", None))  # Append transactions to 'c' list
            if "categories" in i and isinstance(i["categories"], list) and len(i["categories"]) > 0:
                d.append(i["categories"][0].get("title", None))  # Append category name to 'd' list
            else:
                d.append(None)
            e.append(i.get("review_count", None))  # Append review count to 'e' list
            f.append(i.get("rating", None))  # Append rating to 'f' list
    except:
        pass

yelp_df = pd.DataFrame({"name": a, "address1": b, "transactions": c, "category_name": d, "review_count": e, "rating": f})

# Print or do further processing with the dataframe 'df'
print(yelp_df)
# Out:
#                             name                 address1        transactions  \
# 0                   Aba - Austin      1011 S Congress Ave  [pickup, delivery]
# 1                Prim and Proper      1007 S Congress Ave  [pickup, delivery]
# 2                        Red Ash          303 Colorado St          [delivery]
# 3     Summer House on Music Lane            1101 Music Ln                  []
# 4                      Two Hands  1011 South Congress Ave  [pickup, delivery]
# ...                          ...                      ...                 ...
# 1524          Taqueria La Morena         5419 Glissman Rd          [delivery]
# 1525                 Panda Label         5323 Levander Lp                  []
# 1526              Native Grocery           705 Tillery St  [pickup, delivery]
# 1527        Pueblo Viejo Tillery           641 Tillery St                  []
# 1528               Solar Falafel             5305 Bolm Rd                  []
#
#            category_name  review_count  rating
# 0          Mediterranean          1081     4.5
# 1          Cocktail Bars            41     4.5
# 2                Italian          1200     4.5
# 3     Breakfast & Brunch           163     4.0
# 4                   Bars           328     4.0
# ...                  ...           ...     ...
# 1524             Mexican             5     4.0
# 1525             Chinese             0     0.0
# 1526             Grocery            37     4.5
# 1527               Tacos             1     5.0
# 1528             Falafel             0     0.0
#
# [1529 rows x 6 columns]

# %%
yelp_df.head(20)
# Out:
#                                          name                 address1  \
# 0                                Aba - Austin      1011 S Congress Ave
# 1                             Prim and Proper      1007 S Congress Ave
# 2                                     Red Ash          303 Colorado St
# 3                  Summer House on Music Lane            1101 Music Ln
# 4                                   Two Hands  1011 South Congress Ave
# 5                          Joann’s Fine Foods      1224 S Congress Ave
# 6                                  Taco Joint       134 E Riverside Dr
# 7                      Terry Black's Barbecue   1003 Barton Springs Rd
# 8                  Aussie's Grill & Beach Bar    306 Barton Springs Rd
# 9                            Soco Bar & Bites       300 S Congress Ave
# 10                          Austin Rotisserie         111 Congress Ave
# 11                                Lucky Robot      1303 S Congress Ave
# 12                                    Perla's      1400 S Congress Ave
# 13                                    El Alma   1025 Barton Springs Rd
# 14                  Arlo Grey by Kristen Kish    111 E Cesar Chavez St
# 15  Gus's World Famous Fried Chicken - Austin     117 San Jacinto Blvd
# 16                                White Tiger      1321 S Congress Ave
# 17                                 ATX Cocina       110 San Antonio St
# 18                                 Forthright             35 Brazos St
# 19                                 La Piscina             600 W 2nd St
#
#           transactions           category_name  review_count  rating
# 0   [pickup, delivery]           Mediterranean          1081     4.5
# 1   [pickup, delivery]           Cocktail Bars            41     4.5
# 2           [delivery]                 Italian          1200     4.5
# 3                   []      Breakfast & Brunch           163     4.0
# 4   [pickup, delivery]                    Bars           328     4.0
# 5           [delivery]                  Diners           311     4.0
# 6           [delivery]                 Mexican           563     4.5
# 7           [delivery]                Barbeque          6085     4.5
# 8   [pickup, delivery]                    Bars           211     3.0
# 9   [pickup, delivery]           Cocktail Bars            18     4.0
# 10          [delivery]            Comfort Food           162     4.5
# 11  [pickup, delivery]              Sushi Bars          1358     4.0
# 12          [delivery]                 Seafood          1844     4.0
# 13  [pickup, delivery]                 Mexican          1185     4.0
# 14          [delivery]          American (New)           398     4.0
# 15          [delivery]                Southern          3097     4.5
# 16          [delivery]  American (Traditional)            26     4.0
# 17          [delivery]                 Mexican           636     4.0
# 18          [delivery]                   Cafes           813     4.0
# 19          [delivery]                 Mexican            91     4.5

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# The yelp API had a more complete complete data. It contains datas such as ratings, review counts, price, multiple addresses, and multiple phone numbers where applicable.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
# Assuming you have a Yelp DataFrame called 'yelp_df'
top_10_restaurants = yelp_df.sort_values(by='rating', ascending=False).head(10)
top_10_restaurants
# Out:
#                      name                address1        transactions  \
# 226              Ceviche7           502 W 30th St          [delivery]
# 884   The Chuckwagon Cafe         1601 N Congress          [delivery]
# 505            Halal Time           1400 E 6th St  [delivery, pickup]
# 503               Apt 115           2025 E 7th St          [delivery]
# 1481         TraphouseATX         310 Colorado St  [pickup, delivery]
# 826          TraphouseATX         310 Colorado St  [pickup, delivery]
# 488                Bar AC     1901 San Antonio St          [delivery]
# 349         Four Brothers  1720 Barton Springs Rd  [pickup, delivery]
# 172          TraphouseATX         310 Colorado St  [delivery, pickup]
# 1018             Ceviche7           502 W 30th St          [delivery]
#
#                category_name  review_count  rating
# 226                 Peruvian           327     5.0
# 884   American (Traditional)             7     5.0
# 505              Food Trucks           200     5.0
# 503                Wine Bars            87     5.0
# 1481               Caribbean             2     5.0
# 826                Caribbean             2     5.0
# 488                Wine Bars             5     5.0
# 349                Empanadas             1     5.0
# 172                Caribbean             2     5.0
# 1018                Peruvian           327     5.0
